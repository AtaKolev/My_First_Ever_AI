# %%
import main

# %%
import importlib

# %%
importlib.reload(main)
# Out:
# <module 'main' from 'd:\\Repositories\\My_First_Ever_AI\\main.py'>

# %%
main.main()
# Out:
# [['-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' 'S' ' ']
#  [' ' ' ' ' ' '-' '-' ' ' ' ' ' ' '-' '-' ' ']
#  [' ' ' ' ' ' 'S' ' ' ' ' ' ' ' ' ' ' 'R' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  ['O' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  ['-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-']]
# [['-' '-' '-' '-' '-' '-' '-' '-' '-' '-' '-']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' 'S' ' ']
#  [' ' ' ' ' ' '-' '-' ' ' ' ' ' ' '-' '-' ' ']
#  [' ' ' ' ' ' 'S' ' ' ' ' ' ' ' ' ' ' 'R' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
# ...
